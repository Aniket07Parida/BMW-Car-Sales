# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"C:\Users\Dell\Downloads\BMW_Cars.xlsx")
data
# Out:
#     Row_id       year  month               country     model   segment  \
# 0        1 2016-07-01      1  Australia, Melbourne        X1       SUV
# 1        2 2019-08-20      8     Australia, Sydney        i4     Sedan
# 2        3 2020-05-21     12       USA, Washington  5 Series  Electric
# 3        4 2015-06-03     11   Australia, Adelaide        i7       SUV
# 4        5 2015-01-29     12      Brazil, Brasília        X5       SUV
# ..     ...        ...    ...                   ...       ...       ...
# 95      96 2019-06-29      7       USA, Washington  3 Series     Sedan
# 96      97 2015-06-16      3         China, Bajing        i7  Electric
# 97      98 2017-12-27     11       Canada, Toronto  3 Series       SUV
# 98      99 2021-12-20      8      Brazil, Salvador        i4       SUV
# 99     100 2023-10-18      3          Japan, Tokyo        X3       SUV
#
#    engine_type  price_usd  marketing_spend_usd  dealership_count  \
# ...

# %%
drop_column = data.drop(columns=["month"],inplace=True)
data
# Out:
#     Row_id       year               country     model   segment engine_type  \
# 0        1 2016-07-01  Australia, Melbourne        X1       SUV      Petrol
# 1        2 2019-08-20     Australia, Sydney        i4     Sedan    Electric
# 2        3 2020-05-21       USA, Washington  5 Series  Electric      Hybrid
# 3        4 2015-06-03   Australia, Adelaide        i7       SUV    Electric
# 4        5 2015-01-29      Brazil, Brasília        X5       SUV      Diesel
# ..     ...        ...                   ...       ...       ...         ...
# 95      96 2019-06-29       USA, Washington  3 Series     Sedan      Hybrid
# 96      97 2015-06-16         China, Bajing        i7  Electric      Diesel
# 97      98 2017-12-27       Canada, Toronto  3 Series       SUV      Hybrid
# 98      99 2021-12-20      Brazil, Salvador        i4       SUV      Diesel
# 99     100 2023-10-18          Japan, Tokyo        X3       SUV    Electric
#
# ...

# %%
rename_coloumn = data.rename(columns={"year":"Date"},inplace=True)
data
# Out:
#     Row_id       Date               country     model   segment engine_type  \
# 0        1 2016-07-01  Australia, Melbourne        X1       SUV      Petrol
# 1        2 2019-08-20     Australia, Sydney        i4     Sedan    Electric
# 2        3 2020-05-21       USA, Washington  5 Series  Electric      Hybrid
# 3        4 2015-06-03   Australia, Adelaide        i7       SUV    Electric
# 4        5 2015-01-29      Brazil, Brasília        X5       SUV      Diesel
# ..     ...        ...                   ...       ...       ...         ...
# 95      96 2019-06-29       USA, Washington  3 Series     Sedan      Hybrid
# 96      97 2015-06-16         China, Bajing        i7  Electric      Diesel
# 97      98 2017-12-27       Canada, Toronto  3 Series       SUV      Hybrid
# 98      99 2021-12-20      Brazil, Salvador        i4       SUV      Diesel
# 99     100 2023-10-18          Japan, Tokyo        X3       SUV    Electric
#
# ...

# %%
data["Month"] = data["Date"].dt.month_name()
data["Year"] = data["Date"].dt.year
data
# Out:
#     Row_id       Date               country     model   segment engine_type  \
# 0        1 2016-07-01  Australia, Melbourne        X1       SUV      Petrol
# 1        2 2019-08-20     Australia, Sydney        i4     Sedan    Electric
# 2        3 2020-05-21       USA, Washington  5 Series  Electric      Hybrid
# 3        4 2015-06-03   Australia, Adelaide        i7       SUV    Electric
# 4        5 2015-01-29      Brazil, Brasília        X5       SUV      Diesel
# ..     ...        ...                   ...       ...       ...         ...
# 95      96 2019-06-29       USA, Washington  3 Series     Sedan      Hybrid
# 96      97 2015-06-16         China, Bajing        i7  Electric      Diesel
# 97      98 2017-12-27       Canada, Toronto  3 Series       SUV      Hybrid
# 98      99 2021-12-20      Brazil, Salvador        i4       SUV      Diesel
# 99     100 2023-10-18          Japan, Tokyo        X3       SUV    Electric
#
# ...

# %%
Drop_month = data.drop(columns={"month"},inplace=True)
data
# Out:
#     Row_id       Date               country     model   segment engine_type  \
# 0        1 2016-07-01  Australia, Melbourne        X1       SUV      Petrol
# 1        2 2019-08-20     Australia, Sydney        i4     Sedan    Electric
# 2        3 2020-05-21       USA, Washington  5 Series  Electric      Hybrid
# 3        4 2015-06-03   Australia, Adelaide        i7       SUV    Electric
# 4        5 2015-01-29      Brazil, Brasília        X5       SUV      Diesel
# ..     ...        ...                   ...       ...       ...         ...
# 95      96 2019-06-29       USA, Washington  3 Series     Sedan      Hybrid
# 96      97 2015-06-16         China, Bajing        i7  Electric      Diesel
# 97      98 2017-12-27       Canada, Toronto  3 Series       SUV      Hybrid
# 98      99 2021-12-20      Brazil, Salvador        i4       SUV      Diesel
# 99     100 2023-10-18          Japan, Tokyo        X3       SUV    Electric
#
# ...

# %%
data[["Country","City"]] = data["country"].str.split(",",expand=True)
data
# Out:
#     Row_id       Date               country     model   segment engine_type  \
# 0        1 2016-07-01  Australia, Melbourne        X1       SUV      Petrol
# 1        2 2019-08-20     Australia, Sydney        i4     Sedan    Electric
# 2        3 2020-05-21       USA, Washington  5 Series  Electric      Hybrid
# 3        4 2015-06-03   Australia, Adelaide        i7       SUV    Electric
# 4        5 2015-01-29      Brazil, Brasília        X5       SUV      Diesel
# ..     ...        ...                   ...       ...       ...         ...
# 95      96 2019-06-29       USA, Washington  3 Series     Sedan      Hybrid
# 96      97 2015-06-16         China, Bajing        i7  Electric      Diesel
# 97      98 2017-12-27       Canada, Toronto  3 Series       SUV      Hybrid
# 98      99 2021-12-20      Brazil, Salvador        i4       SUV      Diesel
# 99     100 2023-10-18          Japan, Tokyo        X3       SUV    Electric
#
# ...

# %%
# Remove_column = data.drop(columns={"country"},inplace=True)
data
# Out:
#     Row_id       Date     model   segment engine_type  price_usd  \
# 0        1 2016-07-01        X1       SUV      Petrol      82234
# 1        2 2019-08-20        i4     Sedan    Electric      82291
# 2        3 2020-05-21  5 Series  Electric      Hybrid      40594
# 3        4 2015-06-03        i7       SUV    Electric      42371
# 4        5 2015-01-29        X5       SUV      Diesel      82315
# ..     ...        ...       ...       ...         ...        ...
# 95      96 2019-06-29  3 Series     Sedan      Hybrid      62241
# 96      97 2015-06-16        i7  Electric      Diesel      50540
# 97      98 2017-12-27  3 Series       SUV      Hybrid     107255
# 98      99 2021-12-20        i4       SUV      Diesel      99757
# 99     100 2023-10-18        X3       SUV    Electric      76203
#
#     marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0                315372                96            0.97                6.29
# ...

# %%
data
# Out:
#     Row_id       Date     model   segment engine_type  price_usd  \
# 0        1 2016-07-01        X1       SUV      Petrol      82234
# 1        2 2019-08-20        i4     Sedan    Electric      82291
# 2        3 2020-05-21  5 Series  Electric      Hybrid      40594
# 3        4 2015-06-03        i7       SUV    Electric      42371
# 4        5 2015-01-29        X5       SUV      Diesel      82315
# ..     ...        ...       ...       ...         ...        ...
# 95      96 2019-06-29  3 Series     Sedan      Hybrid      62241
# 96      97 2015-06-16        i7  Electric      Diesel      50540
# 97      98 2017-12-27  3 Series       SUV      Hybrid     107255
# 98      99 2021-12-20        i4       SUV      Diesel      99757
# 99     100 2023-10-18        X3       SUV    Electric      76203
#
#     marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0                315372                96            0.97                6.29
# ...

# %%
# Change the Date column only date formating
data["Date"] = pd.to_datetime(data["Date"]).astype("date32[pyarrow]")
data
# Out:
#     Row_id        Date     model   segment engine_type  price_usd  \
# 0        1  2016-07-01        X1       SUV      Petrol      82234
# 1        2  2019-08-20        i4     Sedan    Electric      82291
# 2        3  2020-05-21  5 Series  Electric      Hybrid      40594
# 3        4  2015-06-03        i7       SUV    Electric      42371
# 4        5  2015-01-29        X5       SUV      Diesel      82315
# ..     ...         ...       ...       ...         ...        ...
# 95      96  2019-06-29  3 Series     Sedan      Hybrid      62241
# 96      97  2015-06-16        i7  Electric      Diesel      50540
# 97      98  2017-12-27  3 Series       SUV      Hybrid     107255
# 98      99  2021-12-20        i4       SUV      Diesel      99757
# 99     100  2023-10-18        X3       SUV    Electric      76203
#
#     marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0                315372                96            0.97                6.29
# ...
